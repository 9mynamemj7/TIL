# %%
import json
import numpy as np
import os
import re
import unicodedata

from bokeh.models import HoverTool
from bokeh.palettes import Category20
from bokeh.io import show, output_notebook
from bokeh.plotting import figure, ColumnDataSource
from collections import Counter
from datetime import datetime
from konlpy.tag import Okt
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.manifold import TSNE
from tqdm import tqdm

okt = Okt()
current_path = os.getcwd()
dataset_path = os.path.join(current_path, 'data')

# %%
file_list = os.listdir(dataset_path)
file_list = [os.path.join(dataset_path, file) for _, file in enumerate(file_list) if '.txt' in file]

# %%
date_regex = r'^[\d]{4}년[\s0-9]{1,3}월[\s0-9]{1,3}일[\s][월화수목금토일]요일'
chat_date_regex = r'^[\d]{4}.[\s0-9]{1,3}.[\s0-9]{1,3}.[\s][오전후]{2}[\s][0-9]{1,2}:[0-9]{1,2}'
id_regex = r'^(.*)(?=:)'

# %%
chat_list = []
for _, file in enumerate(tqdm(file_list)):
    with open(file, 'r') as f:
        current_data = f.read()
    
    current_data = unicodedata.normalize('NFKC', current_data)
    splited_list = current_data.split('\n')
    # remove except 'chat data' then, remove the date
    splited_list = [re.sub(chat_date_regex, '', s) for _, s in enumerate(splited_list) if re.match(chat_date_regex, s)]
    # remove id
    splited_list = [re.sub(r'^(.*)(?=:)', '', s) for _, s in enumerate(splited_list)]
    # remove ':'
    splited_list = [re.sub(r'^[: ]+', '', s) for _, s in enumerate(splited_list)]
    chat_list.extend(splited_list)
# Out:
# 100%|██████████| 23/23 [00:01<00:00, 13.86it/s]

# %%
#tag_set = set(['Noun', 'Verb', 'Adjective'])
tag_set = set(['Noun'])

stop_words = set(['채팅', '혹시', '선생님', '그냥', ])

# %%
token_list = []
for _, chat in enumerate(tqdm(chat_list)):
    words = okt.pos(chat, norm=True, stem=True)
    words = [w for (w, tag) in words if tag in tag_set and len(w) > 1 and w not in stop_words]
    if len(words) == 0:
        continue
    
    token_list.append({
        'chat': chat,
        'tokens': words,
    })
# Out:
# 100%|██████████| 180929/180929 [07:57<00:00, 378.70it/s]

# %%
word_counter = Counter()
for _, tokens in enumerate(token_list):
    word_counter.update(tokens['tokens'])

# %%
num_words = 20000
voca = word_counter.most_common(num_words)
word2id = {w:i for i, (w, _) in enumerate(voca)}

# %%
tdm = np.zeros((len(token_list), len(voca)), dtype=np.float32)
for i, chat in enumerate(tqdm(token_list)):
    for word in chat['tokens']:
        if word in word2id:
            tdm[i, word2id[word]] += 1
# Out:
# 100%|██████████| 150271/150271 [00:02<00:00, 70075.18it/s]

# %%
tdm = TfidfTransformer().fit_transform(tdm)

# %%
K = 20
nmf = NMF(n_components=K, max_iter=5000)
W = nmf.fit_transform(tdm)
H = nmf.components_

# %%
for k in range(K):
    print(f"{k+1}th topic")
    keyword_indices = H[k, :].argsort()[::-1][:50]
    for index in keyword_indices:
        print(voca[index], end=' ')
    print()
# Out:
# 1th topic
# ('오픈', 3166) ('바이오', 2625) ('직종', 2432) ('제약', 2884) ('업계', 2875) ('위해', 2663) ('카카오', 296) ('시작', 1076) ('카톡', 232) ('룰루', 40) ('사가', 150) ('국내', 614) ('다른', 1630) ('사도', 92) ('시간', 1761) ('프로필', 70) ('톡방', 171) ('포지션', 288) ('이슈', 444) ('하나', 1539) ('링크', 144) ('챗방', 20) ('분위기', 530) ('기획', 52) ('부탁', 333) ('라벨', 307) ('연락', 1194) ('사면', 51) ('취준님', 368) ('개발', 289) ('여기', 1122) ('공유', 502) ('고민', 920) ('경험', 882) ('사실', 964) ('관련', 1224) ('다시', 1210) ('평균', 150) ('주심', 54) ('근무', 481) ('문제', 1096) ('이유', 523) ('아시', 1791) ('스터디', 508) ('대화', 177) ('계시', 238) ('중견', 57) ('대해', 488) ('우리', 491) ('관심', 202)
# 2th topic
# ('교환', 7147) ('보유', 5163) ('신촌', 1592) ('세브란스', 1554) ('요청', 2201) ('이후', 1335) ('희망', 466) ('신분', 1263) ('강남', 586) ('안암', 279) ('부산', 542) ('하루', 798) ('날짜', 757) ('원함', 255) ('국립', 427) ('구합', 685) ('중순', 188) ('사이', 333) ('자리', 1285) ('연락', 1194) ('빈센트', 143) ('세브란스병원', 221) ('성심', 237) ('중앙대', 147) ('충북대', 150) ('대구', 176) ('완료', 471) ('해운대', 173) ('제외', 438) ('아산병원', 499) ('가능', 318) ('일정', 496) ('건국대', 67) ('신청', 804) ('경희대', 120) ('조선대', 40) ('한양대', 73) ('일자', 207) ('울산', 93) ('인하대', 63) ('강북', 247) ('순천향', 94) ('성모', 1526) ('아무', 220) ('가천', 87) ('센터', 760) ('구리', 77) ('변경', 2027) ('마지막', 315) ('삼성암', 95)
# 3th topic
# ('메시지', 2285) ('삭제', 2005) ('관리자', 503) ('바로', 966) ('문제', 1096) ('메세지', 42) ('내용', 764) ('링크', 144) ('자동', 139) ('완료', 471) ('다운', 213) ('일정', 496) ('변경', 2027) ('톡방', 171) ('개인정보', 151) ('기한', 221) ('궁금', 95) ('공유', 502) ('구진', 315) ('해당', 614) ('업로드', 180) ('메일', 1566) ('전체', 245) ('가요', 1973) ('라면', 722) ('추가', 683) ('시간', 1761) ('기록', 657) ('일부러', 77) ('수정', 492) ('정정', 59) ('질문', 1232) ('자체', 523) ('번호', 576) ('버전', 195) ('카톡', 232) ('다른', 1630) ('분위기', 530) ('제대로', 227) ('버튼', 102) ('공지', 518) ('네네', 844) ('제시', 59) ('얼른', 124) ('계정', 231) ('저장', 191) ('된거', 208) ('어디', 1431) ('가장', 295) ('양도', 1272)
# 4th topic
# ('사진', 1977) ('카톡', 232) ('정장', 61) ('첨부', 128) ('건대', 63) ('면허증', 19) ('사람', 2529) ('타이밍', 54) ('강남', 586) ('친구', 348) ('키트', 105) ('힐링', 51) ('머리', 194) ('프로필', 70) ('삭제', 2005) ('전화', 1028) ('아아', 342) ('저장', 191) ('아래', 125) ('계속', 1141) ('본인', 822) ('잘못', 344) ('번호', 576) ('검사', 1116) ('녹음', 79) ('저희', 946) ('인증', 152) ('뉴스', 80) ('치킨', 76) ('피엠', 96) ('아이폰', 76) ('이분', 77) ('플레인', 72) ('문자', 287) ('추석', 57) ('자가', 100) ('사장', 55) ('고양이', 47) ('하나로', 44) ('자제', 39) ('풍경', 2) ('신분증', 19) ('무슨', 428) ('한판', 10) ('얼집', 8) ('증거', 36) ('안나', 210) ('고먐미', 4) ('제출', 1084) ('가나', 175)
# 5th topic
# ('현직', 3653) ('임상', 142) ('개발', 289) ('어피', 74) ('튜브', 110) ('네오', 91) ('무지', 80) ('라이언', 110) ('제이지', 87) ('퇴근', 397) ('불뚝', 42) ('리비', 19) ('프로도', 59) ('신입', 1520) ('여기', 1122) ('도비', 37) ('운동', 163) ('붕붕', 14) ('기획', 52) ('강퇴', 116) ('뿌뿌', 14) ('이직', 1832) ('양도', 1272) ('치료', 315) ('하이', 29) ('베리', 17) ('부탁', 333) ('라면', 722) ('처리', 383) ('제발', 260) ('제약', 2884) ('세상', 210) ('초보', 57) ('해피', 19) ('코코', 18) ('동이', 20) ('댓글', 178) ('인증', 152) ('피스', 38) ('라라', 16) ('감사', 864) ('모니터', 147) ('에이', 324) ('포도', 16) ('감자', 39) ('오리', 13) ('입장', 385) ('엄지', 33) ('월말', 57) ('크롱', 10)
# 6th topic
# ('이모티콘', 1395) ('감사', 864) ('새해', 68) ('화이팅', 303) ('모두', 826) ('주말', 461) ('오늘', 1405) ('세브란스', 1554) ('축하', 166) ('역시', 356) ('아시', 1791) ('아침', 384) ('월요일', 114) ('추천', 968) ('메리크리스마스', 16) ('눈물', 165) ('예약', 1546) ('연차', 412) ('재미', 49) ('여기', 1122) ('개님', 259) ('정보', 779) ('최고', 215) ('여러분', 232) ('언제', 489) ('내일', 562) ('존경', 56) ('바인더', 527) ('시간', 1761) ('칼퇴', 55) ('뽀뽀', 17) ('나이', 260) ('도대체', 115) ('말씀', 1717) ('자신', 115) ('갑자기', 417) ('보시', 418) ('대충', 140) ('도움', 783) ('부산', 542) ('입사', 611) ('일단', 839) ('멘붕', 112) ('하라', 245) ('아하', 773) ('업무', 1838) ('외근', 580) ('와우', 192) ('해결', 624) ('조금', 609)
# 7th topic
# ('서울대', 4043) ('양도', 1272) ('병원', 4222) ('분당', 401) ('구합', 685) ('자리', 1285) ('교환', 7147) ('신분', 1263) ('구해', 292) ('구함', 142) ('하루', 798) ('이후', 1335) ('아시', 1791) ('보유', 5163) ('신청', 804) ('오늘', 1405) ('취소', 678) ('접속', 230) ('교차', 91) ('원함', 255) ('가요', 1973) ('명단', 156) ('교수', 1838) ('부탁', 333) ('홈페이지', 462) ('에러', 85) ('오류', 141) ('날짜', 757) ('심의', 1264) ('약사', 2191) ('제외', 438) ('코어', 291) ('아무', 220) ('종양', 111) ('비밀번호', 127) ('비번', 188) ('일정', 496) ('연구원', 136) ('계시', 238) ('인증서', 200) ('생명', 138) ('가지', 533) ('인석', 21) ('우수', 211) ('번호', 576) ('가능', 318) ('마지막', 315) ('개님', 259) ('원래', 584) ('로그인', 172)
# 8th topic
# ('진짜', 3389) ('사람', 2529) ('공감', 435) ('고생', 403) ('스트레스', 406) ('대박', 266) ('요즘', 1185) ('오늘', 1405) ('퇴사', 1100) ('하나', 1539) ('한번', 1348) ('여기', 1122) ('교수', 1838) ('개시', 1090) ('얘기', 956) ('과제', 2133) ('최고', 215) ('시간', 1761) ('문제', 1096) ('소리', 289) ('성모', 1526) ('무슨', 428) ('이해', 748) ('사이트', 800) ('최악', 77) ('메일', 1566) ('계속', 1141) ('다행', 290) ('연구', 2203) ('우리', 491) ('때문', 956) ('지금', 1882) ('외근', 580) ('본인', 822) ('처음', 1036) ('기분', 305) ('별로', 538) ('택시', 403) ('전화', 1028) ('소름', 53) ('기억', 575) ('눈물', 165) ('완전', 311) ('노답', 54) ('연락', 1194) ('협조', 128) ('가면', 424) ('충격', 107) ('하루', 798) ('일이', 470)
# 9th topic
# ('아산', 2198) ('서울', 3433) ('성모', 1526) ('양도', 1272) ('보유', 5163) ('구합', 685) ('교환', 7147) ('아산병원', 499) ('희망', 466) ('이후', 1335) ('구해', 292) ('변경', 2027) ('구함', 142) ('아시', 1791) ('하루', 798) ('신분', 1263) ('취소', 678) ('교차', 91) ('심의', 1264) ('오늘', 1405) ('약사', 2191) ('원함', 255) ('자리', 1285) ('요청', 2201) ('어디', 1431) ('중순', 188) ('오전', 210) ('종일', 110) ('완료', 471) ('승인', 1287) ('순천향', 94) ('동도', 131) ('교수', 1838) ('부탁', 333) ('가능', 318) ('계열', 159) ('구비', 654) ('가요', 1973) ('신청', 804) ('전화', 1028) ('시스템', 501) ('우수', 211) ('주소', 275) ('발급', 250) ('사실', 964) ('지방', 306) ('메일', 1566) ('관리', 871) ('인증서', 200) ('공지', 518)
# 10th topic
# ('회사', 4189) ('저희', 946) ('다른', 1630) ('사람', 2529) ('지원', 834) ('지금', 1882) ('퇴사', 1100) ('어디', 1431) ('달라', 833) ('분위기', 530) ('경우', 2865) ('우리', 491) ('과제', 2133) ('이름', 463) ('입사', 611) ('업무', 1838) ('얘기', 956) ('면접', 1228) ('개인', 618) ('일단', 839) ('연차', 412) ('이직', 1832) ('이전', 512) ('별로', 538) ('출근', 398) ('문제', 1096) ('다시', 1210) ('스폰서', 1344) ('그거', 656) ('본인', 822) ('다음', 611) ('연락', 1194) ('라면', 722) ('보통', 2084) ('때문', 956) ('상황', 717) ('계약', 610) ('계속', 1141) ('재택', 469) ('정보', 779) ('내부', 332) ('입장', 385) ('자체', 523) ('아시', 1791) ('예전', 539) ('대해', 488) ('직할', 157) ('조금', 609) ('외국', 331) ('준비', 868)
# 11th topic
# ('답변', 1807) ('감사', 864) ('모두', 826) ('질문', 1232) ('주신', 145) ('시간', 1761) ('메일', 1566) ('문의', 1131) ('쿼리', 338) ('아아', 342) ('고민', 920) ('하루', 798) ('아시', 1791) ('참고', 368) ('상세', 83) ('주시', 232) ('여기', 1122) ('면접', 1228) ('도움', 783) ('군용', 76) ('부분', 865) ('다시', 1210) ('주말', 461) ('조언', 314) ('영어', 1306) ('준비', 868) ('걱정', 512) ('처음', 1036) ('넵넵', 116) ('말씀', 1717) ('관련', 1224) ('이해', 748) ('다른', 1630) ('의견', 496) ('대한', 480) ('해결', 624) ('역시', 356) ('일단', 839) ('바로', 966) ('전화', 1028) ('신분', 1263) ('한번', 1348) ('계속', 1141) ('상황', 717) ('내용', 764) ('하나', 1539) ('방법', 633) ('직접', 704) ('정리', 328) ('글쿤', 61)
# 12th topic
# ('모니터링', 4217) ('예약', 1546) ('병원', 4222) ('약국', 1762) ('양도', 1272) ('세브란스', 1554) ('자리', 1285) ('취소', 678) ('아시', 1791) ('오늘', 1405) ('시간', 1761) ('어디', 1431) ('검사', 1116) ('센터', 760) ('약사', 2191) ('아산병원', 499) ('바인더', 527) ('부산', 542) ('내일', 562) ('대출', 252) ('전화', 1028) ('신분', 1263) ('국립', 427) ('코로나', 687) ('방문', 793) ('강남', 586) ('복사', 217) ('삼성암', 95) ('메일', 1566) ('하나요', 838) ('홈페이지', 462) ('출력', 414) ('가요', 1973) ('임상시험', 1037) ('위치', 190) ('연락', 1194) ('성심', 237) ('프린트', 181) ('분당', 401) ('경험', 882) ('복사기', 95) ('중앙대', 147) ('비번', 188) ('언제', 489) ('처음', 1036) ('분서', 258) ('직접', 704) ('컴퓨터', 162) ('사이트', 800) ('당일', 291)
# 13th topic
# ('생각', 3274) ('사람', 2529) ('지금', 1882) ('다시', 1210) ('시간', 1761) ('업무', 1838) ('본인', 822) ('계속', 1141) ('일단', 839) ('간호사', 831) ('퇴사', 1100) ('개인', 618) ('하나', 1539) ('한번', 1348) ('경험', 882) ('문제', 1096) ('요즘', 1185) ('오늘', 1405) ('다른', 1630) ('부분', 865) ('마음', 553) ('일이', 470) ('고민', 920) ('이유', 523) ('질문', 1232) ('때문', 956) ('거기', 758) ('도움', 783) ('뭔가', 596) ('교수', 1838) ('해도', 614) ('여기', 1122) ('드네', 54) ('입장', 385) ('커리어', 216) ('고생', 403) ('느낌', 606) ('나름', 213) ('시작', 1076) ('만해', 99) ('지원', 834) ('가끔', 331) ('조금', 609) ('제일', 394) ('자기', 477) ('그때', 384) ('나이', 260) ('이제', 721) ('이직', 1832) ('스폰서', 1344)
# 14th topic
# ('삼성', 2846) ('서울', 3433) ('병원', 4222) ('약국', 1762) ('강북', 247) ('보유', 5163) ('구해', 292) ('본관', 306) ('대출', 252) ('구합', 685) ('자리', 1285) ('교차', 91) ('연락', 1194) ('신분', 1263) ('원함', 255) ('교수', 1838) ('삼성암', 95) ('아시', 1791) ('미래', 128) ('검사', 1116) ('내일', 562) ('교환', 7147) ('코로나', 687) ('하루', 798) ('학관', 32) ('별관', 84) ('제외', 438) ('날짜', 757) ('일자', 207) ('이후', 1335) ('지금', 1882) ('마지막', 315) ('중순', 188) ('항원', 123) ('실패', 120) ('온도', 190) ('구함', 142) ('요청', 2201) ('기록', 657) ('시스템', 501) ('교정', 297) ('성적', 221) ('희망', 466) ('약사', 2191) ('하나요', 838) ('결과', 798) ('테크', 82) ('바인더', 527) ('취소', 678) ('사이', 333)
# 15th topic
# ('세브', 1592) ('양도', 1272) ('보유', 5163) ('구합', 685) ('요청', 2201) ('이후', 1335) ('원함', 255) ('자리', 1285) ('구함', 142) ('날짜', 757) ('지금', 1882) ('교차', 91) ('예약', 1546) ('오늘', 1405) ('아산', 2198) ('하루', 798) ('취소', 678) ('삼성암', 95) ('내일', 562) ('중순', 188) ('개님', 259) ('한자리', 113) ('부탁', 333) ('구해', 292) ('문자', 287) ('변경', 2027) ('신분', 1263) ('부터', 213) ('요즘', 1185) ('방생', 24) ('언제', 489) ('잡기', 75) ('하나', 1539) ('주로', 206) ('화이팅', 303) ('제외', 438) ('로그인', 172) ('계시', 238) ('나로', 10) ('차주', 4) ('버거', 25) ('말씀', 1717) ('이틀', 126) ('박스', 101) ('분서', 258) ('대출', 252) ('부인', 12) ('매일', 227) ('탈출', 71) ('와중', 86)
# 16th topic
# ('확인', 2973) ('한번', 1348) ('지금', 1882) ('메일', 1566) ('공지', 518) ('요청', 2201) ('감사', 864) ('댓글', 178) ('다시', 1210) ('시간', 1761) ('검사', 1116) ('사항', 630) ('문의', 1131) ('일정', 496) ('동의', 1527) ('스터디', 508) ('음성', 170) ('연구자', 940) ('약사', 2191) ('약국', 1762) ('경우', 2865) ('부분', 865) ('내용', 764) ('서명', 1250) ('기록', 657) ('기준', 1067) ('강퇴', 116) ('결과', 798) ('대상자', 1175) ('먼저', 522) ('진행', 1291) ('처리', 383) ('규정', 335) ('홈페이지', 462) ('관련', 1224) ('통해', 308) ('오늘', 1405) ('하나요', 838) ('심의', 1264) ('담당자', 520) ('사이트', 800) ('달라', 833) ('다음', 611) ('방문', 793) ('전화', 1028) ('연락', 1194) ('입장', 385) ('명단', 156) ('센터', 760) ('과제', 2133)
# 17th topic
# ('정말', 1795) ('사람', 2529) ('감사', 864) ('말씀', 1717) ('오늘', 1405) ('도움', 783) ('공감', 435) ('하나', 1539) ('마음', 553) ('조언', 314) ('고생', 403) ('여기', 1122) ('질문', 1232) ('다행', 290) ('고민', 920) ('시간', 1761) ('스트레스', 406) ('계속', 1141) ('의견', 496) ('지금', 1882) ('아아', 342) ('모두', 826) ('업무', 1838) ('경우', 2865) ('정보', 779) ('이해', 748) ('하루', 798) ('자리', 1285) ('다시', 1210) ('이야기', 424) ('처음', 1036) ('다른', 1630) ('교수', 1838) ('취소', 678) ('교육', 1136) ('업계', 2875) ('때문', 956) ('기분', 305) ('참고', 368) ('얘기', 956) ('담당', 542) ('일이', 470) ('기본', 382) ('주시', 232) ('걱정', 512) ('한번', 1348) ('주변', 366) ('선택', 341) ('연락', 1194) ('일도', 157)
# 18th topic
# ('글로벌', 2046) ('이직', 1832) ('정도', 2174) ('연봉', 1937) ('로컬', 1389) ('경력', 1909) ('가요', 1973) ('신입', 1520) ('사람', 2529) ('보통', 2084) ('약사', 2191) ('어디', 1431) ('지금', 1882) ('과제', 2133) ('영어', 1306) ('요즘', 1185) ('면접', 1228) ('스폰서', 1344) ('업무', 1838) ('준비', 868) ('시작', 1076) ('여기', 1122) ('고민', 920) ('추천', 968) ('경험', 882) ('바로', 966) ('국내', 614) ('지원', 834) ('거의', 772) ('질문', 1232) ('입사', 611) ('얼마', 488) ('개월', 584) ('퇴사', 1100) ('간호사', 831) ('다른', 1630) ('연구', 2203) ('기준', 1067) ('협상', 242) ('경우', 2865) ('얘기', 956) ('데디', 532) ('처음', 1036) ('인턴', 400) ('차이', 439) ('계속', 1141) ('인정', 306) ('도움', 783) ('사실', 964) ('교육', 1136)
# 19th topic
# ('보고', 3392) ('기관', 2799) ('변경', 2027) ('경우', 2865) ('병원', 4222) ('말씀', 1717) ('연구', 2203) ('종료', 763) ('승인', 1287) ('보통', 2084) ('심의', 1264) ('과제', 2133) ('진행', 1291) ('동의', 1527) ('교수', 1838) ('제출', 1084) ('약사', 2191) ('문의', 1131) ('위반', 465) ('아시', 1791) ('요청', 2201) ('하나', 1539) ('대상자', 1175) ('업무', 1838) ('연구자', 940) ('메일', 1566) ('스폰서', 1344) ('다른', 1630) ('관련', 1224) ('서명', 1250) ('결과', 798) ('질문', 1232) ('기준', 1067) ('기한', 221) ('작성', 784) ('구비', 654) ('내용', 764) ('관리', 871) ('한번', 1348) ('이후', 1335) ('개시', 1090) ('면접', 1228) ('문서', 850) ('등록', 746) ('다시', 1210) ('전화', 1028) ('추가', 683) ('시간', 1761) ('의뢰', 775) ('하나요', 838)
# 20th topic
# ('아하', 773) ('네네', 844) ('말씀', 1717) ('감사', 864) ('넵넵', 116) ('모두', 826) ('이해', 748) ('지금', 1882) ('한번', 1348) ('아아', 342) ('시간', 1761) ('하루', 798) ('설명', 533) ('전화', 1028) ('조언', 314) ('거기', 758) ('취소', 678) ('도움', 783) ('바로', 966) ('방법', 633) ('군용', 76) ('이제', 721) ('내일', 562) ('고민', 920) ('정보', 779) ('걱정', 512) ('문제', 1096) ('저희', 946) ('지원', 834) ('주말', 461) ('의견', 496) ('데디', 532) ('네넵', 69) ('오늘', 1405) ('화이팅', 303) ('공유', 502) ('계속', 1141) ('그거', 656) ('공감', 435) ('대표', 220) ('마자', 184) ('면접', 1228) ('다른', 1630) ('경력', 1909) ('조금', 609) ('오픈', 3166) ('노보텍', 201) ('다시', 1210) ('포지션', 288) ('상황', 717)

# %%
filtered_chat_list = []
for _, token in enumerate(token_list):
    filtered_chat_list.append(token['chat'])

# %%
# select random index
#selectNum = W.shape[0]
selectNum = 20000
randIndex = np.random.choice(W.shape[0], selectNum, replace=False)
randIndex.sort()

tsne = TSNE(n_components=2, init='pca', verbose=1)
W2d = tsne.fit_transform(W[randIndex, :])
topicIndex = [v.argmax() for v in W[randIndex, :]]

tools_to_show = 'hover,box_zoom,pan,save,reset,wheel_zoom'
p = figure(width=800, height=600, tools=tools_to_show)

source = ColumnDataSource(data={
    'x': W2d[:, 0],
    'y': W2d[:, 1],
    'id': [i for i in randIndex],
    'document': [filtered_chat_list[randInd][:100] for randInd in randIndex],  
    'topic': [str(i) for i in topicIndex],  # 토픽 번호
    'color': [Category20[K][i] for i in topicIndex]
})
p.circle(
    'x', 'y',
    source=source,
    legend_label='topic',
    color='color',
    fill_alpha=0.7,
    line_alpha=0.7)

p.legend.location = "top_left"
hover = p.select(dict(type=HoverTool))
hover.tooltips = [("Topic", "@topic"), ('id', '@id'), ("Article", "@document")]
hover.mode = 'mouse'

output_notebook()
show(p)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 20000 samples in 0.001s...
# [t-SNE] Computed neighbors for 20000 samples in 0.610s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 20000
# [t-SNE] Computed conditional probabilities for sample 2000 / 20000
# [t-SNE] Computed conditional probabilities for sample 3000 / 20000
# [t-SNE] Computed conditional probabilities for sample 4000 / 20000
# [t-SNE] Computed conditional probabilities for sample 5000 / 20000
# [t-SNE] Computed conditional probabilities for sample 6000 / 20000
# [t-SNE] Computed conditional probabilities for sample 7000 / 20000
# [t-SNE] Computed conditional probabilities for sample 8000 / 20000
# [t-SNE] Computed conditional probabilities for sample 9000 / 20000
# [t-SNE] Computed conditional probabilities for sample 10000 / 20000
# [t-SNE] Computed conditional probabilities for sample 11000 / 20000
# [t-SNE] Computed conditional probabilities for sample 12000 / 20000
# [t-SNE] Computed conditional probabilities for sample 13000 / 20000
# [t-SNE] Computed conditional probabilities for sample 14000 / 20000
# [t-SNE] Computed conditional probabilities for sample 15000 / 20000
# [t-SNE] Computed conditional probabilities for sample 16000 / 20000
# [t-SNE] Computed conditional probabilities for sample 17000 / 20000
# [t-SNE] Computed conditional probabilities for sample 18000 / 20000
# [t-SNE] Computed conditional probabilities for sample 19000 / 20000
# [t-SNE] Computed conditional probabilities for sample 20000 / 20000
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 75.707588
# [t-SNE] KL divergence after 1000 iterations: 0.939793
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="p1453">Loading BokehJS ...</span>
#     </div>
#   <div id="1d2d1c1a-242d-4ece-bf45-21102fcef08a" data-root-id="p1365" style="display: contents;"></div>
